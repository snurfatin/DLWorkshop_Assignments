# %% [markdown]
# # **Assignment 2: Instruction**
#
# Submission date: 7/10/2022
#
#
# ---
#
#
#
# On kneeXRay dataset, you are required to prepare one notebook that can run on google colab containing:
#
# 1.   The training of a **model on the dataset as is.(as in fruit data notebook)
# 2.   The training of the model using custom CNN of three hidden layers on the dataset after modification with batchnorm and dropout to improve the performance of the model.
# 3.   The training of the model using transfer learning on the dataset
# 4.   Save the final model and load again on the notebook. Perform inference on 3 new samples (provided separately)
#
#
# ---
#
#
#
# * The deliverables: one notebook containing all the codes, model file (.pt file) and inference on three images

# %% [markdown]
# # **Dataset description**
# https://drive.google.com/file/d/1v6aLMBb4w8QkIciqy34Sh_hOFeWQWm9j/view?usp=sharing
#
# This dataset contains knee X-ray data for both knee joint detection and knee KL grading. The Grade descriptions are as follows:
# *   **Grade 0**: Healthy knee image.
# *   **Grade 1** (Doubtful): Doubtful joint narrowing with possible osteophytic lipping
# *   **Grade 2** (Minimal): Definite presence of osteophytes and possible joint space narrowing
# *   **Grade 3** (Moderate): Multiple osteophytes, definite joint space narrowing, with mild sclerosis.
# *   **Grade 4** (Severe): Large osteophytes, significant joint narrowing, and severe sclerosis.
#
#
#
# ---
#
#
#
# ---
#
#
# Acknowledgements:
#
# Chen, Pingjun (2018), “Knee Osteoarthritis Severity Grading Dataset”, Mendeley Data, V1, doi: 10.17632/56rmx5bjcr.1
# The dataset is organized from OAI.

# %%
#mount the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !gdown 1v6aLMBb4w8QkIciqy34Sh_hOFeWQWm9j
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1v6aLMBb4w8QkIciqy34Sh_hOFeWQWm9j
# To: /content/kneeXray.zip
# 100% 145M/145M [00:00<00:00, 164MB/s]

# %%
# !unzip kneeXray.zip -d /content/gdrive/MyDrive/kneeXray_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9687273L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9689906R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9690910L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9690910R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9691359L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9691359R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9692163L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9692604L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9692604R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9692923R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9693364R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9693599L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9693599R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9694101L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9694101R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695317L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695317R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695621L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695881L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695881R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695948L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9695948R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9696350R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9696897L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9696897R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9697904L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9697904R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9699340L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9699340R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9699399L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9699399R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9700163R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9700908L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9700908R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9701362R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9701645L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9701645R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9702644L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703327L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703469L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703469R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703829L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703829R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703978L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9703978R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9704911L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9704911R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9706842L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9706842R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9706954L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9706954R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9707911L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9707911R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9708416L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9708416R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9709164L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9709164R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9710415L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9710415R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9710976R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9713153R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9714513L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9714958L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9715480L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9715626R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9715892L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9716943L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9717685L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9717685R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9717977L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9717977R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9718167L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9721284R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9723032L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9723032R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9724475L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9724475R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9724907L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9725279L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9725914L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9725914R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9727418R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9728026R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9728546R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9728920R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9729215L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9729215R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9729553L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9729553R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9730028L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9730028R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9730488L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9732234L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9732234R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9732727L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9734179L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9735805R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9737043L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9737043R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9737302L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9738052L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9738052R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9739273L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9740738L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9740738R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9741448L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9742563R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9742871L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9743577L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9744568L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9744568R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9745242L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9745242R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9745368L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9746416L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9746585L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9746894L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9747255L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9747255R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9747379L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9747379R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9747589L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9747589R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9748081L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9748081R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9748094L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9748587R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9751625L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9752000L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9752000R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9753414R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9753871L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9753871R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9754338L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9754338R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9754894L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9754894R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9754907L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9754907R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9755372L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9755372R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9756932L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9757487L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9757487R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9759382L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9759382R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9759454L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9759454R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9759956L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9761200L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9761200R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9762412L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9762412R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9762677R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9762713L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9762713R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9763898L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9763898R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9764454R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9764947R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9765419L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9765419R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9765432L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9766449L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9766449R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9767651L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9767651R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9767980R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9768869R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9770003L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9770003R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9770617L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9770617R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9771115L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9771115R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9771214R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9771624L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9771624R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9773633L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9773633R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9775475L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9775475R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9776525R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9776644L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9777014L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9780165L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9780165R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9781279L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9781555L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9781555R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9782690L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9782690R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9785604R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9785684R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9785978R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9786191R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9787204R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9787305L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9787305R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9787576L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9787693L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9788503L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9788503R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9788608L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9788979L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9788979R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789297L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789297R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789504L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789504R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789712L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789767L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9789767R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9790287L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9790287R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9791525L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9791525R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9794140L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9794140R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9794269L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9794269R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9794849L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9794849R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9795183L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9795183R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9795559L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9797352R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9798131L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9798131R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9798351R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9798668L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9798668R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9800154L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9800154R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9800893L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9800893R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9801130L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9801130R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9802372L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9802372R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9802822L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9802822R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9803621L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9803621R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9805234L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9805234R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9805321L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9805321R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9805639L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9805639R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9806950L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9806950R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9808689L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9808689R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9809342L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9809342R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9811200L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9811940L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9812166L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9812166R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9812739L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9812739R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9813353L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9813353R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9813851L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9813851R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9815467L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9815467R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9815779L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9815779R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9816138R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9816968L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9817141L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9817141R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9817618L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9817618R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9819149L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9819149R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9820271L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9821982L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9824703R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9825282L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9825282R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9825783R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9828044L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9828044R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9828518R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9829221L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9829221R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9830316L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9832457L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9832457R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9833489R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9833782R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9833809R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9833835L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9833835R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9834533L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9834533R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9834806L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9834806R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9835291L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9835291R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836062L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836062R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836330L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836547L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836547R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836553L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836553R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9836853L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837054L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837054R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837324L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837324R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837774L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837774R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9837987L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841058L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841058R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841269L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841269R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841364L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841364R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841815L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9841838L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9843822L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9844581L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9846783L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9846783R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9846846L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9847480L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9847480R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9848263L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9849852L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9850237L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9850237R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9850845L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9850845R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9851631L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9851631R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9853065L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9853065R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9853267L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9853267R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9853562L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854226L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854226R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854269L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854269R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854620L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854620R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854837L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9854837R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9855059R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9855117R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9855149R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9856561R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9856744L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9856744R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9857351L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9857351R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9860637L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9860739L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9860739R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9861303L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9861560L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9861560R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9861699R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862541L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862541R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862725L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862725R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862741L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862741R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862772L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9862772R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9863321L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9863321R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9863737L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9864266L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9865771L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9865771R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9866291R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9866764L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9866764R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9867611L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9867611R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9867760R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9868006L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9868006R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9869252L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9869252R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9871097L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9871097R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9871786L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9871786R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9872535L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9872535R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9872789L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9872789R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9872828R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9873057L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9873057R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9873103L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9873103R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9874784L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9875794R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9876530L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9876530R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9876792L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9876792R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9877295L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9877295R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878114L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878114R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878614L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878614R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878765L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878765R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878786L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9878786R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9879069L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9879069R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9880782L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9880782R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9881756L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9881756R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9882788L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9884710L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9884710R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9885303R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9886696R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9888515L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9888561L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9888561R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9888600L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9888600R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9889523L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9889793L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9889793R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9890264L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9890414L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9890414R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9891264R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9891421L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9891421R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9892241L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9892241R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9892270L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9892736L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9892736R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9893482R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9893793L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9893793R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9894048L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9894048R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9894184R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9894795L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9894795R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9895178L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9895178R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9895750R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9896242R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9896710L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9896710R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9896743R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9897170L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9897279L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9897279R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9898582L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9898582R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9898713L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9898713R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9900208L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9900208R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9900967L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9900967R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9901158L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9901199L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9901199R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9902235L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9902576L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9902900R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9903020L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9904667L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9904667R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9905766L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9905766R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9906491L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9906491R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9907090L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9907767R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9908665L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9908665R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9909311L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9909311R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9909790L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9909861L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9909861R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9910268L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9910391L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9911082L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9911082R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9911237L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9911237R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9911265L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9911575L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9912228L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9912275R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9913590L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9913590R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9914231L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9914231R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9914944R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9915540L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9915540R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9916249L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9916249R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9916274L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9916274R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9917505L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9918304L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9919499L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9921353R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9921586L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9921811L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9923099L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9923099R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9923837L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9923837R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9924324L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9924324R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9925376L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9925376R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9926617L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9927318R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9928844L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9929413L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9929413R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9929823R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9930368L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9930368R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9930620R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9930863L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9931342L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9931342R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9931370L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9931370R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9932578L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9932750L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9932750R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9933085L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9933085R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9933955L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9933955R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/train/0/9934310L.png
# ...
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9800368R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9804376R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9809710L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9809710R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9815509L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9818478L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9818478R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9819273L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9819273R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9855267L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9860507L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9860568L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9866738L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9878871L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9878871R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9886520R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9889762L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9895555L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9901658R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9903093L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9903093R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9905383R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9906998L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9906998R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9919568R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9922855L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9922855R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9926602L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9938327L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9949821R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9951159L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9962232R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9971710R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9984279L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9984279R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9986207L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9986207R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9989309R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9995849R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9997869R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/2/9999295R.png
#    creating: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9023348L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9026695L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9034812L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9052956L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9055512L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9055512R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9057265L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9057265R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9070207L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9102858L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9102858R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9107980R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9115049R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9122908L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9160401L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9176924L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9177337L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9179789L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9179789R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9191788L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9195845R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9206535R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9217481L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9217481R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9246518R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9267648R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9275159R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9280249L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9281187L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9285212L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9294761L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9313233R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9331465R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9334156L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9334156R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9352437L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9352437R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9360034L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9360202L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9361974L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9361974R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9364366L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9364366R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9368622R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9375300L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9389580L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9389580R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9409250L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9409250R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9437407L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9445105R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9457264L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9459371R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9466320R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9468561L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9469520R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9495960R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9499893L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9499893R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9505796L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9505796R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9512864R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9518267L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9518267R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9553149R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9568706L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9568706R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9572718L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9572718R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9579255L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9620647R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9657464L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9657464R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9690400R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9739777L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9739777R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9745596L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9757953R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9766889R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9775403L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9775403R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9792327L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9792327R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9806159L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9860507R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9866738R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9879774R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9886598R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9895555R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9914273L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9914273R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9916542R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9919023L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9919023R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9919568L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9920298L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9920298R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9926602R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9928272R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9934064L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9943317L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9947240L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9947240R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9989309L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9991580L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/3/9995849L.png
#    creating: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9070207R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9086204R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9115049L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9127180L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9177337R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9230504R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9235666R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9267719R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9284795L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9387265L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9395979R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9511862R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9512864L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9549818R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9617213R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9627172R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9637958R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9645612L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9693806R.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9757953L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9800368L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9818359L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9824005L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9928082L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9961951L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9971710L.png
#  extracting: /content/gdrive/MyDrive/kneeXray_dataset/kneeXray/validation/4/9997856L.png

# %% [markdown]
# # Q1 - Model training as in fruit_dataset notebook

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

# %%
# Applying Transforms to the Data
import torchvision
import torchvision.transforms as transforms

image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
# Load the Data

# Set train and valid directory paths

from google.colab import drive
drive.mount('/content/gdrive')

dataset = '/content/gdrive/My Drive/kneeXray_dataset/kneeXray'

train_directory = os.path.join(dataset, 'train')
test_directory = os.path.join(dataset, 'validation')

# Batch size
batchSize = 32

# Number of classes
num_classes = len(os.listdir(train_directory))
print(num_classes)

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),

    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
}

# Get a mapping of the indices to the class names, in order to see the output classes of the test images.
# idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
# print(idx_to_class)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 5

# %% [markdown]
# Let's see the info on train dataset

# %%
data['train']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 5778
#     Root location: /content/gdrive/My Drive/kneeXray_dataset/kneeXray/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(256, 256), scale=(0.8, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#                RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# Size of Data, to be used for calculating Average Loss and Accuracy
train_data_size = len(data['train'])
# valid_data_size = len(data['valid'])
test_data_size = len(data['test'])

# Create iterators for the Data loaded using DataLoader module
trainloader = DataLoader(data['train'], batch_size=batchSize, shuffle=True)
# valid_data_loader = DataLoader(data['valid'], batch_size=batchSize, shuffle=True)
testloader = DataLoader(data['test'], batch_size=batchSize, shuffle=True)

# %%
train_data_size, test_data_size
# Out:
# (5778, 826)

# %%
input_size = (3,32,32)

# %%
# #######################################################
# #                  Create Dataloader                     #
# #######################################################

# # Turn train and test custom Dataset's into DataLoader's
# from torch.utils.data import DataLoader
# trainloader = DataLoader(dataset=data['train'], # use custom created train Dataset
#                                      batch_size=4, # how many samples per batch?
#                                      num_workers=0, # how many subprocesses to use for data loading? (higher = more)
#                                      shuffle=True) # shuffle the data?

# testloader = DataLoader(dataset=data['test'], # use custom created test Dataset
#                                     batch_size=4, 
#                                     num_workers=0, 
#                                     shuffle=False) # don't usually need to shuffle testing data

# train_data_size = len(trainloader.dataset)
# test_data_size = len(testloader.dataset)

# print(train_data_size)
# print(test_data_size)

# %%
#######################
# DEFINE YOUR OWN MODEL

model_ft = models.convnext_tiny(pretrained=True)
num_ftrs = model_ft.classifier[2].in_features
# Here the size of each output sample is set to 5.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.classifier[2] = nn.Linear(num_ftrs, 5)

#######################

# 2. LOSS AND OPTIMIZER
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# 3. move the model to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model_ft.to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ConvNeXt_Tiny_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Tiny_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
#   0%|          | 0.00/109M [00:00<?, ?B/s]
# ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0058823529411764705, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.011764705882352941, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.017647058823529415, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.023529411764705882, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.029411764705882353, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.03529411764705883, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0411764705882353, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.047058823529411764, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.052941176470588235, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.058823529411764705, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.06470588235294118, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07058823529411766, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07647058823529412, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0823529411764706, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08823529411764706, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.09411764705882353, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=768, out_features=5, bias=True)
#   )
# )

# %%
import time # to calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'kneeXray_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
# 4. Train the model for 10 epochs
 
num_epochs = 10
trained_model, history = train_and_validate(model_ft, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/10
# Epoch : 000, Training: Loss: 1.4175, Accuracy: 39.1139%,
# 		Validation : Loss : 1.4031, Accuracy: 39.7094%, Time: 1738.2944s
# Epoch: 2/10
# Epoch : 001, Training: Loss: 1.4036, Accuracy: 39.3908%,
# 		Validation : Loss : 1.3932, Accuracy: 39.7094%, Time: 191.2982s
# Epoch: 3/10
# Epoch : 002, Training: Loss: 1.3824, Accuracy: 39.4946%,
# 		Validation : Loss : 1.3122, Accuracy: 41.6465%, Time: 194.5368s
# Epoch: 4/10
# Epoch : 003, Training: Loss: 1.1811, Accuracy: 49.4981%,
# 		Validation : Loss : 1.0623, Accuracy: 54.3584%, Time: 196.2469s
# Epoch: 5/10
# Epoch : 004, Training: Loss: 1.0570, Accuracy: 55.4690%,
# 		Validation : Loss : 1.0303, Accuracy: 56.4165%, Time: 195.3693s
# Epoch: 6/10
# Epoch : 005, Training: Loss: 0.9782, Accuracy: 57.7362%,
# 		Validation : Loss : 0.9325, Accuracy: 61.1380%, Time: 195.7434s
# Epoch: 7/10
# Epoch : 006, Training: Loss: 0.9402, Accuracy: 60.4708%,
# 		Validation : Loss : 0.8859, Accuracy: 63.0751%, Time: 195.4011s
# Epoch: 8/10
# Epoch : 007, Training: Loss: 0.9345, Accuracy: 60.3842%,
# 		Validation : Loss : 0.8807, Accuracy: 62.3487%, Time: 195.4705s
# Epoch: 9/10
# Epoch : 008, Training: Loss: 0.8848, Accuracy: 62.5822%,
# 		Validation : Loss : 0.8762, Accuracy: 61.5012%, Time: 195.7261s
# Epoch: 10/10
# Epoch : 009, Training: Loss: 0.8655, Accuracy: 63.3956%,
# 		Validation : Loss : 0.9244, Accuracy: 61.5012%, Time: 195.3170s

# %%
# 5. Analyze the loss curve

history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,3)
# plt.savefig('kneeXray_loss_curve.png')
plt.show()

# %%
# 6. Analyze the accuracy curve

plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
# plt.savefig('kneeXray_accuracy_curve.png')
plt.show()

# %% [markdown]
# # Q2 - Model training using custom CNN of three hidden layers with batchnorm and dropout

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

# %%
# Applying Transforms to the Data
import torchvision
import torchvision.transforms as transforms

image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.Resize(64),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.Resize(64),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
# Load the Data

# Set train and valid directory paths

from google.colab import drive
drive.mount('/content/gdrive')

dataset = '/content/gdrive/My Drive/kneeXray_dataset/kneeXray'

train_directory = os.path.join(dataset, 'train')
test_directory = os.path.join(dataset, 'validation')

transform = transforms.Compose(
    [transforms.Resize(64),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
     ])

# Batch size
batchSize = 32

# Number of classes
num_classes = len(os.listdir(train_directory))
print(num_classes)

# Classes
classes = ('0', '1', '2', '3', '4')

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
                                  #transform=transform),

    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
                                 #transform=transforms)
}

# Get a mapping of the indices to the class names, in order to see the output classes of the test images.
# idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
# print(idx_to_class)
# Out:
# Mounted at /content/gdrive
# 5

# %%
# Size of Data, to be used for calculating Average Loss and Accuracy
train_data_size = len(data['train'])
# valid_data_size = len(data['valid'])
test_data_size = len(data['test'])

# Create iterators for the Data loaded using DataLoader module
trainloader = DataLoader(data['train'], batch_size=batchSize, shuffle=True)
# valid_data_loader = DataLoader(data['valid'], batch_size=batchSize, shuffle=True)
testloader = DataLoader(data['test'], batch_size=batchSize, shuffle=False)

# %%
#1. DEFINE THE CNN 
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, 5)  #arguments: in_channels, out_channels, kernel_size
        self.pool = nn.MaxPool2d(2, 2)
        self.batchnorm = nn.BatchNorm2d(10)
        self.conv2 = nn.Conv2d(10, 15, 3)
        self.batchnorm2 = nn.BatchNorm2d(15)
        self.conv3 = nn.Conv2d(15, 20, 3)
        self.fc1 = nn.Linear(20 * 6 * 6, 100)
        self.dropout = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(100, 200)
        self.fc3 = nn.Linear(200, 10)
        self.fc4 = nn.Linear(10, 5)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.batchnorm(x)
        x = self.pool(self.relu(self.conv2(x)))
        x = self.batchnorm2(x)
        x = self.pool(self.relu(self.conv3(x)))
        x = x.view(-1, 20 * 6 * 6)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
model = CNN() # need to instantiate the network to be used in instance method

# 2. LOSS AND OPTIMIZER
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# 3. move the model to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# CNN(
#   (conv1): Conv2d(3, 10, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (batchnorm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(10, 15, kernel_size=(3, 3), stride=(1, 1))
#   (batchnorm2): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(15, 20, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=720, out_features=100, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=100, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=10, bias=True)
#   (fc4): Linear(in_features=10, out_features=5, bias=True)
#   (relu): ReLU()
# )

# %%
import time # to calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'kneeXray_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
import torch
from torchvision import models
from torchsummary import summary

model = CNN()
model.to(device)
summary(model, (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 10, 60, 60]             760
#               ReLU-2           [-1, 10, 60, 60]               0
#          MaxPool2d-3           [-1, 10, 30, 30]               0
#        BatchNorm2d-4           [-1, 10, 30, 30]              20
#             Conv2d-5           [-1, 15, 28, 28]           1,365
#               ReLU-6           [-1, 15, 28, 28]               0
#          MaxPool2d-7           [-1, 15, 14, 14]               0
#        BatchNorm2d-8           [-1, 15, 14, 14]              30
#             Conv2d-9           [-1, 20, 12, 12]           2,720
#              ReLU-10           [-1, 20, 12, 12]               0
#         MaxPool2d-11             [-1, 20, 6, 6]               0
#            Linear-12                  [-1, 100]          72,100
#              ReLU-13                  [-1, 100]               0
#           Dropout-14                  [-1, 100]               0
#            Linear-15                  [-1, 200]          20,200
#              ReLU-16                  [-1, 200]               0
#            Linear-17                   [-1, 10]           2,010
#              ReLU-18                   [-1, 10]               0
#            Linear-19                    [-1, 5]              55
# ================================================================
# Total params: 99,260
# Trainable params: 99,260
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.97
# Params size (MB): 0.38
# Estimated Total Size (MB): 1.39
# ----------------------------------------------------------------

# %%
# 4. Train the model for 10 epochs

num_epochs = 10
trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/10
# Epoch : 000, Training: Loss: 1.6023, Accuracy: 13.3091%,
# 		Validation : Loss : 1.6037, Accuracy: 12.8329%, Time: 3453.7542s
# Epoch: 2/10
# Epoch : 001, Training: Loss: 1.6024, Accuracy: 13.3091%,
# 		Validation : Loss : 1.6038, Accuracy: 12.8329%, Time: 27.3194s
# Epoch: 3/10
# Epoch : 002, Training: Loss: 1.6026, Accuracy: 13.2226%,
# 		Validation : Loss : 1.6038, Accuracy: 12.8329%, Time: 28.1381s
# Epoch: 4/10
# Epoch : 003, Training: Loss: 1.6022, Accuracy: 13.3264%,
# 		Validation : Loss : 1.6037, Accuracy: 12.8329%, Time: 27.2008s
# Epoch: 5/10
# Epoch : 004, Training: Loss: 1.6022, Accuracy: 13.4129%,
# 		Validation : Loss : 1.6037, Accuracy: 12.8329%, Time: 27.4416s
# Epoch: 6/10
# Epoch : 005, Training: Loss: 1.6025, Accuracy: 13.2918%,
# 		Validation : Loss : 1.6036, Accuracy: 12.8329%, Time: 27.3929s
# Epoch: 7/10
# Epoch : 006, Training: Loss: 1.6025, Accuracy: 13.2226%,
# 		Validation : Loss : 1.6037, Accuracy: 12.8329%, Time: 28.4102s
# Epoch: 8/10
# Epoch : 007, Training: Loss: 1.6024, Accuracy: 13.3091%,
# 		Validation : Loss : 1.6038, Accuracy: 12.8329%, Time: 27.2820s
# Epoch: 9/10
# Epoch : 008, Training: Loss: 1.6026, Accuracy: 13.3437%,
# 		Validation : Loss : 1.6038, Accuracy: 12.8329%, Time: 27.3411s
# Epoch: 10/10
# Epoch : 009, Training: Loss: 1.6024, Accuracy: 13.4476%,
# 		Validation : Loss : 1.6037, Accuracy: 12.8329%, Time: 27.2925s

# %%
# 5. Analyze the loss curve

history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,3)
# plt.savefig('kneeXray_loss_curve.png')
plt.show()

# %%
# 6. Analyze the accuracy curve

plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
# plt.savefig('kneeXray_accuracy_curve.png')
plt.show()

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
#         images, labels = data
        images, labels = data[0].to(device), data[1].to(device)
        # calculate outputs by running images through the network
#         images = images.view(images.size(0), -1)
        outputs = model(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the 10000 test images: {100 * correct // total} %')
# Out:
# Accuracy of the network on the 10000 test images: 12 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
#         images = images.view(images.size(0), -1)
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: 0     is 0.0 %
# Accuracy for class: 1     is 0.0 %
# Accuracy for class: 2     is 0.0 %
# Accuracy for class: 3     is 100.0 %
# Accuracy for class: 4     is 0.0 %

# %% [markdown]
# # Q3 - Model training using transfer learning

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

# %%
# Applying Transforms to the Data
import torchvision
import torchvision.transforms as transforms

image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
# Load the Data

# Set train and valid directory paths

from google.colab import drive
drive.mount('/content/gdrive')

dataset = '/content/gdrive/My Drive/kneeXray_dataset/kneeXray'

train_directory = os.path.join(dataset, 'train')
test_directory = os.path.join(dataset, 'validation')

# Batch size
batchSize = 32

# Number of classes
num_classes = len(os.listdir(train_directory))
print(num_classes)

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),

    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
}

# Get a mapping of the indices to the class names, in order to see the output classes of the test images.
# idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
# print(idx_to_class)
# Out:
# Mounted at /content/gdrive
# 5

# %% [markdown]
# Let's see the info on train dataset

# %%
data['train']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 5778
#     Root location: /content/gdrive/My Drive/kneeXray_dataset/kneeXray/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(256, 256), scale=(0.8, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#                RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# Size of Data, to be used for calculating Average Loss and Accuracy
train_data_size = len(data['train'])
# valid_data_size = len(data['valid'])
test_data_size = len(data['test'])

# Create iterators for the Data loaded using DataLoader module
trainloader = DataLoader(data['train'], batch_size=batchSize, shuffle=True)
# valid_data_loader = DataLoader(data['valid'], batch_size=batchSize, shuffle=True)
testloader = DataLoader(data['test'], batch_size=batchSize, shuffle=True)

# %%
train_data_size, test_data_size
# Out:
# (5778, 826)

# %%
input_size = (3,32,32)

# %%
#######################
# DEFINE YOUR OWN MODEL

model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 5.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 5)

#######################

# 2. LOSS AND OPTIMIZER
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# 3. move the model to GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model_ft.to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
import time # to calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'kneeXray_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
# 4. Train the model for 10 epochs
 
num_epochs = 10
trained_model, history = train_and_validate(model_ft, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/10
# Epoch : 000, Training: Loss: 1.3111, Accuracy: 44.6521%,
# 		Validation : Loss : 1.1668, Accuracy: 50.3632%, Time: 1246.4406s
# Epoch: 2/10
# Epoch : 001, Training: Loss: 1.0879, Accuracy: 53.6864%,
# 		Validation : Loss : 1.1241, Accuracy: 53.1477%, Time: 47.7712s
# Epoch: 3/10
# Epoch : 002, Training: Loss: 0.9823, Accuracy: 58.1862%,
# 		Validation : Loss : 0.9714, Accuracy: 59.5642%, Time: 48.3352s
# Epoch: 4/10
# Epoch : 003, Training: Loss: 0.9183, Accuracy: 61.0592%,
# 		Validation : Loss : 1.1018, Accuracy: 56.2954%, Time: 47.5951s
# Epoch: 5/10
# Epoch : 004, Training: Loss: 0.9040, Accuracy: 61.8207%,
# 		Validation : Loss : 0.9304, Accuracy: 60.6538%, Time: 47.5698s
# Epoch: 6/10
# Epoch : 005, Training: Loss: 0.8637, Accuracy: 63.4303%,
# 		Validation : Loss : 0.9221, Accuracy: 62.1065%, Time: 48.1772s
# Epoch: 7/10
# Epoch : 006, Training: Loss: 0.8530, Accuracy: 63.8802%,
# 		Validation : Loss : 0.9233, Accuracy: 61.6223%, Time: 47.3044s
# Epoch: 8/10
# Epoch : 007, Training: Loss: 0.8467, Accuracy: 63.6552%,
# 		Validation : Loss : 0.9225, Accuracy: 62.8329%, Time: 47.6571s
# Epoch: 9/10
# Epoch : 008, Training: Loss: 0.8209, Accuracy: 65.0917%,
# 		Validation : Loss : 0.9137, Accuracy: 62.5908%, Time: 47.9961s
# Epoch: 10/10
# Epoch : 009, Training: Loss: 0.8048, Accuracy: 66.0609%,
# 		Validation : Loss : 0.8862, Accuracy: 62.7119%, Time: 47.6084s

# %%
# 5. Analyze the loss curve

history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,3)
# plt.savefig('kneeXray_loss_curve.png')
plt.show()

# %%
# 6. Analyze the accuracy curve

plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
# plt.savefig('kneeXray_accuracy_curve.png')
plt.show()

# %% [markdown]
# # Q4 - Inference on 3 new samples

# %%
#export your model's weights for future use
from google.colab import files
files.download('/content/kneeXray_model_9.pt')

# %%
transform = transforms.Compose([transforms.ToPILImage(),         
                                transforms.Resize(256),                    
                                transforms.CenterCrop(224),                
                                transforms.ToTensor(),                     
                                transforms.Normalize(                      
                                    mean=[0.485, 0.456, 0.406],                
                                    std=[0.229, 0.224, 0.225]                  
                                )])

classes = ['0_normal', '1_doubtful', '2_mild', '3_moderate', '4_severe']

# %%
img = cv2.imread("/content/gdrive/MyDrive/Assignment Test/0_9243046_1.png")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
   
img_t = transform(img)

input_batch = torch.unsqueeze(img_t, 0)
input_batch = input_batch.to(device)
trained_model.eval()

# Carry out inference
out = trained_model(input_batch)

from google.colab.patches import cv2_imshow

# Get the softmax probabilities.
probabilities = torch.nn.functional.softmax(out, dim=1)[0]
# Check the 5 categories that are predicted.
top5_prob, top5_catid = torch.topk(probabilities, 5)

cv2.putText(img, f"{top5_prob[0].item()*100:.3f}%", (15, (1)*30), 
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA)
cv2.putText(img, f"{classes[top5_catid[0]]}", (160, (1)*30), 
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA)
print(classes[top5_catid[0]], top5_prob[0].item())
    
cv2_imshow(img)
# Out:
# 0_normal 0.8844651579856873
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4EBA4583D0>

# %%
img = cv2.imread("/content/gdrive/MyDrive/Assignment Test/2_9487842_1.png")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
   
img_t = transform(img)

input_batch = torch.unsqueeze(img_t, 0)
input_batch = input_batch.to(device)
trained_model.eval()

# Carry out inference
out = trained_model(input_batch)

from google.colab.patches import cv2_imshow

# Get the softmax probabilities.
probabilities = torch.nn.functional.softmax(out, dim=1)[0]
# Check the 5 categories that are predicted.
top5_prob, top5_catid = torch.topk(probabilities, 5)

cv2.putText(img, f"{top5_prob[0].item()*100:.3f}%", (15, (1)*30), 
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA)
cv2.putText(img, f"{classes[top5_catid[0]]}", (160, (1)*30), 
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA)
print(classes[top5_catid[0]], top5_prob[0].item())
    
cv2_imshow(img)
# Out:
# 1_doubtful 0.44425666332244873
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4EBA3DC490>

# %%
img = cv2.imread("/content/gdrive/MyDrive/Assignment Test/4_9390064_1.png")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
   
img_t = transform(img)

input_batch = torch.unsqueeze(img_t, 0)
input_batch = input_batch.to(device)
trained_model.eval()

# Carry out inference
out = trained_model(input_batch)

from google.colab.patches import cv2_imshow

# Get the softmax probabilities.
probabilities = torch.nn.functional.softmax(out, dim=1)[0]
# Check the 5 categories that are predicted.
top5_prob, top5_catid = torch.topk(probabilities, 5)

cv2.putText(img, f"{top5_prob[0].item()*100:.3f}%", (15, (1)*30), 
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA)
cv2.putText(img, f"{classes[top5_catid[0]]}", (160, (1)*30), 
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 255), 2, cv2.LINE_AA)
print(classes[top5_catid[0]], top5_prob[0].item())
    
cv2_imshow(img)
# Out:
# 3_moderate 0.7817655205726624
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4EBA340CD0>
